# %%
#from google.colab import files
#uploaded = files.upload()

# %%
#!unzip re.zip

# %%
# !ls
# Out:
# re  readme.md  re.zip  sample_data

# %%
#!pip install tensorflow-gpu
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import sklearn

# %%
import cv2

# %%
data = os.listdir('re/')
images=[]
d=[]
for item in data:
    d.append(item)
    path="re/"+str(item)
    image = cv2.imread(str(path))

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    image = cv2.resize(image,(224,224))
    images.append(image)
print (len(images))
# Out:
# 9

# %%
label = [0,8,2,5,9,7,1,6,3]
print (image[0].shape)
# Out:
# (224, 3)

# %%
def random_plotting(im1,im2,im3):
    plt.figure(figsize=(16,16))
    plt.subplot(141)
    plt.imshow(images[im1])
    plt.subplot(142)
    plt.imshow(images[im2])
    plt.subplot(143)
    plt.imshow(images[im3])

# %%
random_plotting(4,5,6)

# %%
print (len(images))
print (len(label))
# Out:
# 9
# 9

# %%
plt.imshow(images[7])
print(label[7])

## you have to see and than match with the other pic and set the lavel manually
#3 there is another pic where you find the sing meaning
# Out:
# 6

# %%
from tensorflow.keras.utils import normalize

# %%
#X = normalize(images)

# %%
X=images
y=label
print (X)
# Out:
# [array([[[162, 162, 162],
#         [162, 162, 162],
#         [162, 162, 162],
#         ...,
#         [161, 161, 161],
#         [161, 161, 161],
#         [162, 162, 162]],
#
#        [[161, 161, 161],
#         [161, 161, 161],
#         [161, 161, 161],
#         ...,
#         [162, 162, 162],
#         [162, 162, 162],
#         [162, 162, 162]],
#
#        [[161, 161, 161],
#         [161, 161, 161],
#         [161, 161, 161],
#         ...,
#         [163, 163, 163],
#         [163, 163, 163],
#         [163, 163, 163]],
#
#        ...,
#
#        [[166, 166, 166],
#         [166, 166, 166],
#         [166, 166, 166],
#         ...,
#         [166, 166, 166],
#         [165, 165, 165],
#         [165, 165, 165]],
#
#        [[166, 166, 166],
#         [166, 166, 166],
#         [166, 166, 166],
#         ...,
#         [166, 166, 166],
#         [166, 166, 166],
#         [165, 165, 165]],
#
#        [[166, 166, 166],
#         [166, 166, 166],
#         [166, 166, 166],
# ...

# %%
plt.imshow(X[7])

# %%
print(len(X))

#X = pd.DataFrame({'index':d,'feature':X})
# Out:
# 9

# %%
import tensorflow as tf
import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D


X = tf.keras.utils.normalize(X, axis=1)  # scales data between 0 and 1
#x_test = tf.keras.utils.normalize(x_test, axis=1)  # scales data between 0 and 1

model = tf.keras.models.Sequential()  # a basic feed-forward model
model.add(tf.keras.layers.Flatten())  # takes our 28x28 and makes it 1x784
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))  # our output layer. 10 units for 10 classes. Softmax for probability distribution

model.compile(optimizer='adam',  # Good default optimizer to start with
              loss='sparse_categorical_crossentropy',  # how will we calculate our "error." Neural network aims to minimize loss.
              metrics=['accuracy'])  # what to track

model.fit(X, np.array(y), epochs=15)  # train the model

val_loss, val_acc = model.evaluate(X, y)  # evaluate the out of sample data with model
print(val_loss)  # model's loss (error)
print(val_acc)  # model's accuracy
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Using TensorFlow backend.
# Epoch 1/15
# 9/9 [==============================] - 1s 61ms/sample - loss: 2.3002 - acc: 0.2222
# Epoch 2/15
# 9/9 [==============================] - 0s 3ms/sample - loss: 5.3968 - acc: 0.1111
# Epoch 3/15
# 9/9 [==============================] - 0s 3ms/sample - loss: 4.7042 - acc: 0.1111
# Epoch 4/15
# 9/9 [==============================] - 0s 3ms/sample - loss: 3.7122 - acc: 0.1111
# Epoch 5/15
# 9/9 [==============================] - 0s 3ms/sample - loss: 2.7126 - acc: 0.1111
# Epoch 6/15
# 9/9 [==============================] - 0s 3ms/sample - loss: 2.4479 - acc: 0.2222
# Epoch 7/15
# ...

# %%
data=model.predict(X)

# %%
data[0]
# Out:
# array([0.6525527 , 0.02099086, 0.08943036, 0.04121462, 0.00195003,
#        0.01510658, 0.02332548, 0.06388234, 0.01106379, 0.08048321],
#       dtype=float32)

# %%
print(np.argmax(data[7]))
# Out:
# 6

# %%
print(np.argmax(data[2]))
# Out:
# 2

# %%
plt.imshow(X[2])
